# %%
import matplotlib.pyplot as plt

# Sample data
flow_energy = [2.524688, 3.19478, 0.1485, 13.280301, 2.437898, 0.283381, 6.067621, 0.228492, 2.311193, 3.190501, 0.586836, 2.802799, 4.785695, 0.990048, 11.154564, 0.261654]

PSNR = [35.5405, 43.8083, 39.7532, 40.8884, 40.0599, 39.6421, 39.1616, 37.8486, 40.3633, 42.3414, 39.238, 35.8291, 37.278, 33.6428, 48.1034, 39.9341]

# Plotting the scatter plot
plt.scatter(flow_energy, PSNR, marker='o', color='b')

# Adding labels and title
plt.xlabel('flow energy')
plt.ylabel('PSNR')
#plt.title('Scatter Plot of Points')
plt.legend()  # Display the legend

# Display the plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np

# Calculate the correlation coefficient
correlation_coefficient = np.corrcoef(flow_energy, PSNR)[0, 1]

print(f"Correlation Coefficient: {correlation_coefficient}")
# Out:
# Correlation Coefficient: 0.4878851151828138
